# %%
import pandas as pd

# %%
df = pd.DataFrame({'tip':[1.01,1.86,3.50,3.31,5.8],'smoker':['no','no','yes','yes','yes']})

# %%
from sklearn.preprocessing import TargetEncoder
enc = TargetEncoder()
trans = enc.fit_transform(df,df['tip'])
trans
# Out:
# array([[3.6175    , 1.86      ],
#        [3.405     , 1.01      ],
#        [2.995     , 4.25823072],
#        [3.0425    , 4.38405197],
#        [2.42      , 3.40084427]])

# %%
import numpy as np
X = np.array([["dog"] * 20 + ["cat"] * 30 + ["snake"] * 38], dtype=object).T
y = [90.3] * 5 + [80.1] * 15 + [20.4] * 5 + [20.1] * 25 + [21.2] * 8 + [49] * 30

# %%
enc = TargetEncoder(smooth=5000)
enc.fit_transform(X,y)
# Out:
# array([[42.82779577],
#        [44.66104681],
#        [44.13182957],
#        [42.82779577],
#        [43.56458066],
#        [43.56458066],
#        [44.66104681],
#        [43.56458066],
#        [43.56458066],
#        [43.56458066],
#        [42.82779577],
#        [42.82779577],
#        [42.82779577],
#        [46.86933367],
#        [44.13182957],
#        [43.56458066],
#        [44.13182957],
#        [43.56458066],
#        [44.66104681],
#        [44.13182957],
#        [43.34538166],
#        [42.5976111 ],
#        [46.62164623],
#        [43.34538166],
#        [46.62164623],
#        [44.41597767],
#        [44.41597767],
#        [46.62164623],
#        [46.62164623],
#        [43.88992182],
#        [43.88992182],
#        [43.88992182],
#        [46.62164623],
#        [42.5976111 ],
#        [43.88992182],
#        [46.62164623],
#        [44.41597767],
#        [42.5976111 ],
#        [42.5976111 ],
#        [42.5976111 ],
#        [46.62164623],
#        [43.88992182],
#        [44.41597767],
#        [43.34538166],
#        [43.34538166],
#        [46.62164623],
#        [44.41597767],
#        [44.41597767],
#        [46.62164623],
#        [43.34538166],
#        [46.707691  ],
#        [44.00418714],
#        [44.00418714],
#        [43.47455144],
#        [43.47455144],
#        [44.52035225],
#        [43.47455144],
#        [43.47455144],
#        [44.00418714],
#        [42.7044118 ],
#        [44.52035225],
#        [46.707691  ],
#        [44.52035225],
#        [44.00418714],
#        [46.707691  ],
#        [44.00418714],
#        [46.707691  ],
#        [42.7044118 ],
#        [44.52035225],
#        [44.52035225],
#        [44.52035225],
#        [46.707691  ],
#        [46.707691  ],
#        [46.707691  ],
#        [44.00418714],
#        [42.7044118 ],
#        [46.707691  ],
#        [44.00418714],
#        [42.7044118 ],
#        [43.47455144],
#        [42.7044118 ],
#        [44.00418714],
#        [44.00418714],
#        [44.52035225],
#        [42.7044118 ],
#        [43.47455144],
#        [44.52035225],
#        [42.7044118 ]])
