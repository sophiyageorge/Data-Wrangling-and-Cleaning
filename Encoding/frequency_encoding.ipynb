# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('mercedesbenz.csv',usecols=['X1','X2'])
df.head()
# Out:
#   X1  X2
# 0  v  at
# 1  t  av
# 2  w   n
# 3  t   n
# 4  v   n

# %%
pd.get_dummies(df)
# Out:
#        X1_a  X1_aa  X1_ab   X1_b   X1_c   X1_d   X1_e   X1_f   X1_g   X1_h  \
# 0     False  False  False  False  False  False  False  False  False  False
# 1     False  False  False  False  False  False  False  False  False  False
# 2     False  False  False  False  False  False  False  False  False  False
# 3     False  False  False  False  False  False  False  False  False  False
# 4     False  False  False  False  False  False  False  False  False  False
# ...     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 4204  False  False  False  False  False  False  False  False  False  False
# 4205  False  False  False  False  False  False  False  False  False  False
# 4206  False  False  False  False  False  False  False  False  False  False
# 4207  False  False  False  False  False  False  False  False  False  False
# 4208  False  False  False  False  False  False  False  False  False  False
#
#       ...   X2_n   X2_o   X2_p   X2_q   X2_r   X2_s   X2_t   X2_x   X2_y  \
# 0     ...  False  False  False  False  False  False  False  False  False
# 1     ...  False  False  False  False  False  False  False  False  False
# 2     ...   True  False  False  False  False  False  False  False  False
# 3     ...   True  False  False  False  False  False  False  False  False
# 4     ...   True  False  False  False  False  False  False  False  False
# ...   ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 4204  ...  False  False  False  False  False  False  False  False  False
# 4205  ...  False  False  False  False  False  False   True  False  False
# 4206  ...  False  False  False  False   True  False  False  False  False
# 4207  ...  False  False  False  False  False  False  False  False  False
# 4208  ...  False  False  False  False  False  False  False  False  False
#
#        X2_z
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# ...     ...
# 4204  False
# 4205  False
# 4206  False
# 4207  False
# 4208  False
#
# [4209 rows x 71 columns]

# %%
len(df['X1'].unique())
# Out:
# 27

# %%
len(df['X2'].unique())
# Out:
# 44

# %%
for col in df.columns[0:]:
    print(col,':',len(df[col].unique()), 'labels')
# Out:
# X1 : 27 labels
# X2 : 44 labels

# %%
df_frequency_map= df.X2.value_counts().to_dict()

# %%
df.X2 = df.X2.map(df_frequency_map)
df.head()
# Out:
#   X1   X2
# 0  v    6
# 1  t    4
# 2  w  137
# 3  t  137
# 4  v  137
