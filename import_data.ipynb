# %%
import pandas as pd

# %%
pf= pd.read_excel('data.xlsx')
pf
# Out:
#                                            Unnamed: 0  \
# 0                          Full Name (As per ID card)
# 1                                              Domain
# 2                                        Joining Date
# 3                                       Date of Birth
# 4                                                 Age
# 5                                              Gender
# 6                                       Father's Name
# 7                                    Father's Contact
# 8                                       Mother's Name
# 9                                    Mother's Contact
# 10                                   Name of Guardian
# 11                         Relationship with Guardian
# 12                                 Guardian's Contact
# 13  Permanent Address As per ID Card (House No, Po...
# 14  Address of Communication (House No, Post Offic...
# 15                                            Village
# ...
